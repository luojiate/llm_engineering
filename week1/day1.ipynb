# %% [markdown]
# # 你的第一個實驗室（Lab）
#
# ### 請閱讀本節。這對你的準備工作很有價值，即使篇幅較長——內容很重要。
#
# ### 另外，請務必閱讀 [README.md](../README.md)！關於更新影片的更多資訊請見 README 與[課程資源頁面（紫色區塊）](https://edwarddonner.com/2024/11/13/llm-engineering-resources/)
#
# ## 你的第一個前沿模型 LLM 專案
#
# 課程結束時，你將建構一個由 7 個代理協作解決商業問題的自主代理式 AI 方案。一切會循序漸進！我們先從較小的專案開始……
#
# 我們的目標是撰寫一種新型網頁瀏覽器：給它一個 URL，它會回傳摘要。《讀者文摘》版的網際網路！
#
# 開始之前，請先完成 README 中的環境設定。
#
# ### 若你初次使用「Notebook」（也稱為 Lab 或 Jupyter Lab）
#
# 歡迎來到資料科學實驗的精彩世界！只要點選內含程式碼的每個「儲存格」（cell），例如緊接本段文字下方的儲存格，然後按 Shift+Return 執行。請從上到下依序執行每個儲存格。
#
# 請到 [Guides 資料夾](../guides/01_intro.ipynb) 查看所有指南。
#
# ## 我隨時可以提供協助
#
# 若你有任何問題，請隨時聯繫。
# 可透過課程平台、ed@edwarddonner.com，或 https://www.linkedin.com/in/eddonner/ 與我聯繫（我很樂意交流！）
# 我也有 [YouTube 頻道提供額外內容](https://youtube.com/@edward.donner)。
# 這對我來說也是新嘗試，我也在 X 上試用 [@edwarddonner](https://x.com/edwarddonner)——若你也在 X 上，請教教我怎麼用 😂
#
# ## 更多疑難排解
#
# 請參閱 setup 資料夾中的 [troubleshooting](../setup/troubleshooting.ipynb) notebook，以診斷並修復常見問題。最後附有診斷腳本，可提供實用的除錯資訊。
#
# ## 若你已熟悉這些內容！
#
# 若你今天的主題已經很熟練，請耐心跟上；前幾個 lab 可以快速通過——隨著週次推進，我們會愈來愈深入。最終我們將微調自己的 LLM，與 OpenAI 一較高下！
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">請閱讀——重要說明</h2>
#             <span style="color:#900;">我與你協作的方式可能與你上過的其他課程不同。我不喜歡在你觀看時邊打程式碼，而是執行像這樣的 Jupyter Lab，讓你建立直覺。建議你在看完講座<b>之後</b>，仔細自己執行一遍。加入 print 語句以理解發生了什麼，再嘗試自己的變化。若有 Github 帳號，可用來展示你的變化。這不僅是重要練習，也能向他人（包括未來的客戶或雇主）展示你的能力……</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">本程式碼為即時資源——留意我的電子郵件</h2>
#             <span style="color:#f71;">我會定期推送程式碼更新。隨著學員提問，我會加入更多範例或改進說明。因此你會發現下方程式碼與影片不完全相同；影片中的內容都在這裡，我也加入了更好的說明與 DeepSeek 等新模型。可把它當作互動式書籍。<br/><br/>
#                 我會定期發送與課程相關的重要更新電子郵件。可在 Udemy 左側欄的「Announcements」找到。也可在 Udemy 通知設定中選擇接收我的郵件。我尊重你的收件匣，並盡力讓每封郵件都有價值！
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">這些練習的商業價值</h2>
#             <span style="color:#181;">最後一點。雖然我設計這些 notebook 是為了教學，也盡量讓它們有趣——我們會讓 LLM 講笑話、互相辯論等。但根本上，我的目標是教會你可在商業中應用的技能。我會在過程中說明商業意涵，值得記住：隨著你累積模型與技術的經驗，思考如何在工作場合立即應用。若想進一步討論或交流想法，請聯繫我。</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### 如有需要，請安裝 Cursor 擴充功能
#
# 1. 從 View 選單選擇 Extensions
# 2. 搜尋 Python
# 3. 點選 ms-python 出品的「Python」，若尚未安裝則點選 Install
# 4. 搜尋 Jupyter
# 5. 點選 ms-toolsai 出品的「Jupyter」，若尚未安裝則點選 Install
#
#
# ### 接著選擇核心（Kernel）
#
# 點選右上角的「Select Kernel」
#
# 選擇「Python Environments...」
#
# 然後選擇類似 `.venv (Python 3.12.x) .venv/bin/python` 的項目——應標示為「Recommended」並有星號。
#
# 有問題嗎？請前往 troubleshooting。
#
# ### 注意：每個 notebook 都需要重新設定核心（Kernel）……

# %%
# 匯入

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# 若執行此儲存格時出錯，請前往 troubleshooting notebook！

# %% [markdown]
# # 連線至 OpenAI（或 Ollama）
#
# 下一個儲存格會載入 `.env` 檔案中的環境變數並連線至 OpenAI。
#
# 若你想改用免費的 Ollama，請參閱 README 的「Free Alternative to Paid APIs」章節；若不確定如何操作，solutions 資料夾中有完整解法（day1_with_ollama.ipynb）。
#
# ## 若遇到問題，請疑難排解：
#
# 若出現「Name Error」——是否已從上到下執行所有儲存格？請參閱 Python Foundations 指南，有可靠方法找出並修復所有 Name Error。
#
# 若仍無法解決，請前往 [troubleshooting](../setup/troubleshooting.ipynb) notebook，依步驟找出根本原因並修復！
#
# 或聯繫我！透過平台訊息或電郵 ed@edwarddonner.com，我們會一起搞定。
#
# 擔心 API 費用？請見 README 中的說明——費用應很低，且你可隨時控制。也可使用 Ollama 作為免費替代方案，我們會在 Day 2 討論。

# %%
# 載入名為 .env 的檔案中的環境變數

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# 檢查 API 金鑰

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

# %% [markdown]
# # 讓我們快速呼叫前沿模型作為預覽！

# %%
# 預覽——用這些 messages 呼叫 OpenAI 就是這麼簡單。若有問題，請前往 Troubleshooting notebook。

message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content

# %% [markdown]
# ## 好，繼續我們的第一個專案

# %%
# 試試這個工具函式

ed = fetch_website_contents("https://edwarddonner.com")
print(ed)

# %% [markdown]
# ## 提示詞類型
#
# 你可能已經知道——若還不知道，你很快就會非常熟悉！
#
# 像 GPT 這類模型經過訓練，會以特定方式接收指示。
#
# 它們預期收到：
#
# **系統提示詞（system prompt）**：告訴模型要執行什麼任務、使用什麼語氣
#
# **使用者提示詞（user prompt）**——開啟對話的內容，模型應據此回覆

# %%
# 定義系統提示詞——之後可實驗修改，例如將最後一句改為「以西班牙文 markdown 回覆」

system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# 定義使用者提示詞

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %% [markdown]
# ## Messages
#
# OpenAI 的 API 預期以特定結構接收 messages。
# 許多其他 API 也採用相同結構：
#
# ```python
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
# ```
# 預覽一下，接下來 2 個儲存格會做相當簡單的呼叫——我們還不會考驗強大的 GPT！

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

response = openai.chat.completions.create(model="gpt-4.1-nano", messages=messages)
response.choices[0].message.content

# %% [markdown]
# ## 現在讓我們用函式為 GPT-4.1-mini 建構實用的 messages

# %%
# 看看此函式如何建立與上方完全相同的格式

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
# 試試看，再試幾個網站

messages_for(ed)

# %% [markdown]
# ## 是時候整合在一起了——OpenAI 的 API 非常簡單！

# %%
# 現在：呼叫 OpenAI API。你會非常熟悉這個流程！

def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")

# %%
# 用 markdown 在輸出中漂亮地顯示結果的函式

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")

# %% [markdown]
# # 再試更多網站
#
# 注意：這只適用於可用此簡易方式抓取的網站。
#
# 以 Javascript 渲染的網站（如 React 應用）無法顯示。community-contributions 資料夾有 Selenium 實作可繞過此限制。需自行了解如何安裝 Selenium（問 ChatGPT！）
#
# 受 CloudFront（及類似服務）保護的網站可能回傳 403 錯誤——感謝 Andy J 指出。
#
# 但許多網站都能正常運作！

# %%
display_summary("https://cnn.com")

# %%
display_summary("https://anthropic.com")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">商業應用</h2>
#             <span style="color:#181;">在本練習中，你首次體驗呼叫前沿模型（AI 前沿的領先模型）的雲端 API。課程中我們會多次使用 OpenAI 等 API，同時也會建構自己的 LLM。
#
# 更具體地說，我們將此應用於摘要（Summarization）——經典的 Gen AI 用例。可應用於任何商業領域：摘要新聞、財務表現、履歷用於求職信等，應用無限。思考摘要如何應用於你的業務，並嘗試製作原型。</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">繼續之前——現在請自己試試</h2>
#             <span style="color:#900;">使用下方儲存格做一個簡單的商業範例。暫時仍專注於摘要用例。想法：撰寫可讀取電子郵件內容並建議合適簡短主旨的程式——這類功能可能內建於商業郵件工具。</span>
#         </td>
#     </tr>
# </table>

# %%
# 步驟 1：建立提示詞

system_prompt = "something here"
user_prompt = """
    Lots of text
    Can be pasted here
"""

# 步驟 2：建立 messages 清單

messages = [] # 在此填入

# 步驟 3：呼叫 OpenAI
# response =

# 步驟 4：印出結果
# print(

# %% [markdown]
# ## 給喜歡網頁抓取的額外練習
#
# 你可能注意到 `display_summary("https://openai.com")` 無法運作！因為 OpenAI 網站使用 Javascript。若你有經驗，有許多解法，例如 Selenium 是熱門框架，在背景執行瀏覽器、渲染頁面並允許查詢。若你熟悉 Selenium、Playwright 等，歡迎改進 Website 類別以使用它們。community-contributions 資料夾有學員的 Selenium 範例（感謝！）

# %% [markdown]
# # 分享你的程式碼
#
# 若你之後能分享程式碼，我會很樂意轉給其他人！你會注意到部分學員已做出修改（含 Selenium 實作），可在 community-contributions 資料夾找到。若要將修改加入該資料夾，請提交 Pull Request，我會合併你的變更。
#
# 若你不熟悉 git（我也不熟！），guides 資料夾的 guide 3 有完整說明，在此重貼：
#
# PR 的整體步驟與關鍵說明：
# https://edwarddonner.com/pr
#
# 提交前請確認：
# 1. PR 僅包含 community-contributions 的變更（除非我們已討論過）
# 2. 所有 notebook 輸出已清除
# 3. 總程式碼少於 2,000 行，檔案不要太多
# 4. 不要包含不必要的測試檔、過長的 README 或 .env.example、emoji 或其他 LLM 產物！
#
# 非常感謝！
#
# 詳細步驟：
#
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b
