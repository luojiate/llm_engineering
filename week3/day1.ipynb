# %% [markdown]
# # Colab 介紹
#
# 在此了解 Google Colab，若尚未有 Google 帳號請先設定 [連結](https://colab.research.google.com/)
#
# 免費或低額度方案應足以完成本課所有專案。我個人訂了 Colab Pro+ 很滿意 — 但非必要。
#
# 要看 Colab 能做什麼，請點下方連結！
#
# https://colab.research.google.com/drive/1DjcrYDZldAXKJ08x1uYIVCtItoLPk1Wr?usp=sharing
