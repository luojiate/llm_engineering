# %% [markdown]
# # Python 基礎與修復 NameError
#
# ## 首先，給完全新手
#
# 此入門教學幫你從基礎開始。
#
# https://chatgpt.com/share/68063082-c2d8-8012-8d45-fa674aa1c1ed

# %% [markdown]
# ## 接著：Python 綜合簡報
#
# 這部分交給 AI 朋友，因為說明與範例寫得很好。把程式範例貼到新 cell 試試。選你想複習的章節即可。
#
# **Python imports：**
# https://chatgpt.com/share/672f9f31-8114-8012-be09-29ef0d0140fb
#
# **Python functions**（含預設參數）：
# https://chatgpt.com/share/672f9f99-7060-8012-bfec-46d4cf77d672
#
# **Python strings**（含切片、split/join、replace、字面量）：
# https://chatgpt.com/share/672fb526-0aa0-8012-9e00-ad1687c04518
#
# **Python f-strings**（含數字與日期格式）：
# https://chatgpt.com/share/672fa125-0de0-8012-8e35-27918cbb481c
#
# **Python lists、dicts 與 sets**（含 `get()`）：
# https://chatgpt.com/share/672fa225-3f04-8012-91af-f9c95287da8d
#
# **Python files**（含模式、編碼、context manager、Path、glob.glob）：
# https://chatgpt.com/share/673b53b2-6d5c-8012-a344-221056c2f960
#
# **Python classes：**
# https://chatgpt.com/share/672fa07a-1014-8012-b2ea-6dc679552715
#
# **Pickling Python 物件與轉 JSON：**
# https://chatgpt.com/share/673b553e-9d0c-8012-9919-f3bb5aa23e31

# %% [markdown]
# ## 在此前提下——理解 Python 的 NameError
#
# 在 Python 中遇到 NameError 很常見。有基礎後，你應能自行除錯。
#
# Notebook 中最常見原因是未依序執行所有 cell，Kernel 尚未定義某變數。
#
# 若不確定如何修 NameError，請閱讀此 [入門指南](https://chatgpt.com/share/67958312-ada0-8012-a1d3-62b3a5fcbbfc) 與此 [含練習的進階指南](https://chatgpt.com/share/67a57e0b-0194-8012-bb50-8ea76c5995b8)，做到很有信心為止。
#
# 內容有些重複，若已熟悉可跳過。
#
# 之後 NameError 不應再困擾你！
