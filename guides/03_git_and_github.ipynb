# %% [markdown]
# # Git 與 GitHub

# %% [markdown]
# 本指南介紹原始碼版本控制：Git 與 GitHub。
#
# 讀完後，你應能自信處理日常版控流程，包括拉取最新程式碼與提交 PR 合併你的變更。

# %% [markdown]
# ### 基礎簡報
#
# 以下是給 PC 或 Mac 使用者的 Git 與 GitHub 介紹：
#
# https://chatgpt.com/share/68061486-08b8-8012-97bc-3264ad5ebcd4

# %% [markdown]
# ### 拉取最新程式碼
#
# 我會定期為課程新增範例、練習與材料。
#
# 以下是取得最新內容的方法——簡易版與嚴謹版：
#
# https://chatgpt.com/share/6806178b-0700-8012-836f-7e87b2670b7b

# %% [markdown]
# ### 將你的變更貢獻回 repo，與他人分享
#
# 非常感謝你的貢獻，這對所有學員都有價值，我也樂見！此外，你會在 GitHub 上獲得 contributor 認可。
#
# PR 整體流程與關鍵步驟：
# https://edwarddonner.com/pr
#
# 提交前請確認：
# 1. PR 僅包含 community-contributions 的變更（除非我們事先另有約定）
# 2. 你的 notebook 能從頭到尾執行
# 3. 你已在 PR 描述中說明變更內容
#
# 感謝你讓課程對所有人更好！

# %% [markdown]
# ### 若想成為 Git 高手
#
# 若想深入 Git，這是極佳指南。讀完你會比我更懂！
#
# https://beej.us/guide/bggit/
