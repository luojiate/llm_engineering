# %% [markdown]
# # 命令列

# %% [markdown]
# 歡迎閱讀本指南，建立你在命令列工作的信心。
#
# 讀完後，你應能自信地在命令列建立目錄、移動檔案等！

# %% [markdown]
# ## Windows PC 使用者
#
# 請閱讀此簡報：
#
# https://chatgpt.com/share/68064acf-4d3c-8012-86a1-fb09a7c6f923

# %% [markdown]
# ## Mac 使用者
#
# 請閱讀此簡報：
#
# https://chatgpt.com/share/68064bfe-662c-8012-8073-479c32595459

# %% [markdown]
# 請多實驗以建立信心。
#
# ChatGPT、Claude、Gemini、DeepSeek 等都能詳細解釋命令列指令。這會很快變成第二天性。
