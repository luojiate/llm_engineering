# %% [markdown]
# # 第 7 週 第 1 天
#
# # 「猜價格」（THE PRICE IS RIGHT）Capstone 專案
#
# 本週目標：微調（fine-tune）一個開源模型！
#
# 一個能根據商品描述，估算價格的模型。
#
# # 進行順序
#
# 第 1 天：QLoRA
# 第 2 天：Prompt 資料與基礎模型
# 第 3 天：訓練（第一部分）
# 第 4 天：訓練（第二部分）
# 第 5 天：評估

# %% [markdown]
# 請在 Google Colab 中查看此 notebook：
#
# https://colab.research.google.com/drive/1oE6jCl8yUxsT1V4N43BD_0Wx5u0A9AQe?usp=sharing
