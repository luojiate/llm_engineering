# %% [markdown]
# # 收集必要診斷資訊
#
# ## 請執行下一 cell 收集重要資料
#
# 請執行下一 cell；網路測試約需一分鐘。
# 然後把最後一個 cell 的輸出寄給 ed@edwarddonner.com。
# 或者：會產生 report.txt——直接附檔寄出即可。

# %%
# 執行我的診斷報告以收集除錯關鍵資訊
# 請把結果寄給我。可複製貼上輸出，或附上 report.txt

# !pip install -q requests speedtest-cli psutil setuptools
from diagnostics import Diagnostics
Diagnostics().run()
